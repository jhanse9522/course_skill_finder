# %% [markdown]
# - Reading in file -- a sample of data -- to view layout
# - Read in as string
# - Loop over lines by splitting on the new lines and creating lists of lines

# %%
fhand = open("/Users/jamey_hansen/Documents/Pycharm_projects/IS_452/Experiments/DPS_Stage4", "r")
filein = fhand.read()  # my text string
fhand.close()

lines = filein.split("/n")  # my text as list of lines
for line in lines:
    print(line)
# Out:
# 1)
#
# Course_Title:
# IS 452AG/AU 2019 Syllabus
# Instructor information
# •	Instructor: Nigel Bosch
# •	Office: 4040 NCSA (National Center for Supercomputing Applications)
# •	Email: pnb@illinois.edu
#
# Course description
# This course covers the common data and document processing constructs and programming concepts used in library and information science. The history, strengths and weaknesses of the techniques are evaluated in the context of our discipline. These constructs and techniques form the basis of applications in areas such as bibliographic records management, full text management and multimedia. No prior programming background is assumed. The first half of the course will focus on programming essentials in Python, and the second half will have us explore other applications and how to integrate the fundamentals to solve more complex problems.
# Informal learning goals
# ...

# %%
#!conda install -c conda-forge spacy --yes
# !python -m spacy download en
# Out:
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /opt/anaconda3/lib/python3.7/site-packages/en_core_web_sm -->
# /opt/anaconda3/lib/python3.7/site-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
import re # remove punctuation
import nltk  #use nltk for tokenization, stemming, lemmatizing
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("averaged_perceptron_tagger")
nltk.download("wordnet")
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
stopwords = set(stopwords.words("english"))
import spacy
# || from part_of_speech import get_part_of_speech  # get method to identify pos
nlp = spacy.load("en") # load spacy -- English
doc = nlp(filein) # pass in text to spacy nlp object, filein string is the text-15 syllabi



cleaned = re.sub('\W+', ' ', filein) # substitute space in place of one or more non alphanumberic character (clean punctuation)
tokenized = word_tokenize(cleaned) # split cleaned strings based on spaces into tokenized objects - words
no_stop_tokenized = [word for word in tokenized if not word in stopwords] # list of words excluding stopwords
print("token objects without stop words: ")
print(no_stop_tokenized)  
print()
print()
tagged = nltk.pos_tag(no_stop_tokenized)# tag list of words excluding stopwords by part of speech
print("TYPE:")
print(type(tagged))  # check to see why tagged didn't work, it's a list!
print("tagged token objects:")
print(tagged)
print(tagged[0])  # testing new idea of how to access token and part of speech to get lemmatized words
print(tagged[0][0])  # planning to use i in a loop and hard code position of token and part of speech since they don't change
print(tagged[0][1])  # I'm able to access token and part of speech this way so will try in my reference range loop
print(tagged[1])
print(tagged[2][0])
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/jamey_hansen/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jamey_hansen/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/jamey_hansen/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/jamey_hansen/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# token objects without stop words:
# ...

# %%
stemmer = PorterStemmer() # instantiate a stemmer
stemmed = [stemmer.stem(token) for token in no_stop_tokenized] # build a list of stemmed tokens from the list of no_stop_tokenized word list

lemmatized = [token.lemma_ for token in doc]

#lemmatizer = WordNetLemmatizer() # instantiate a lemmatizer

#lemmatized = [lemmatizer.lemmatize(tagged[i][0],tagged[i][1]) for i in range(len(no_stop_tokenized))] # build a list of lemmatized tokens by passing in the part of speech and token to the lemmatizer as params
# above, attempting to access token, tag using 
#for token in no_stop_tokenized -- within range of its length -- get param 1 indexing in to access token--zeroeth position of tuple,
# get param 2, indexing in to access tagged part of speech--first position of tuple

# or try (if able to use spacy)

#for token in doc:   # using spacy's doc object (sequence of token objects) to tokenize/tag pos; word->list of words
# print(token, token.pos_)  # param 1- token object, param 2- token object part of speech
    
print("stemmed:")
print()
print(stemmed)
print()
print()
print("lemmatized:")
print()
print(lemmatized)
# Out:
# stemmed:
#
# ...

# %%
tagged
# Out:
# [('course_title', 'NN'),
#  ('IS', 'VBZ'),
#  ('452AG', 'CD'),
#  ('AU', 'NNP'),
#  ('Foundations', 'NNP'),
#  ('Information', 'NNP'),
#  ('Processing', 'NNP'),
#  ('end_title_line', 'NN'),
#  ('other_stuff', 'NN'),
#  ('Instructor', 'NNP'),
#  ('Nigel', 'NNP'),
#  ('Bosch', 'NNP'),
#  ('Office', 'NNP'),
#  ('4040', 'CD'),
#  ('NCSA', 'NNP'),
#  ('National', 'NNP'),
#  ('Center', 'NNP'),
#  ('Supercomputing', 'NNP'),
#  ('Applications', 'NNP'),
#  ('Email', 'NNP'),
#  ('pnb', 'NN'),
#  ('illinois', 'NN'),
#  ('edu', 'JJ'),
#  ('course_description', 'NN'),
#  ('This', 'DT'),
#  ('course', 'NN'),
#  ('covers', 'VBZ'),
#  ('common', 'JJ'),
#  ('data', 'NNS'),
#  ('document', 'NN'),
#  ('processing', 'NN'),
#  ('constructs', 'NNS'),
#  ('programming', 'VBG'),
#  ('concepts', 'NNS'),
#  ('used', 'VBN'),
#  ('library', 'JJ'),
#  ('information', 'NN'),
#  ('science', 'NN'),
#  ('The', 'DT'),
#  ('history', 'NN'),
#  ('strengths', 'JJ'),
#  ('weaknesses', 'NNS'),
#  ('techniques', 'NNS'),
# ...

# %%
#   ignore -- lemmatizer.lemmatize('Processing', pos = 'NNP')

# %% [markdown]
# *Named Entity Recognition*

# %%
for entity in doc.ents:
    print(entity.text, entity.label_)
# Out:
# Nigel Bosch PERSON
# 4040 CARDINAL
# National Center for Supercomputing Applications ORG
# The first half DATE
# Python GPE
# second ORDINAL
# Minimal Wins PERSON
# Run PERSON
# Speak PERSON
# Act PERSON
# Detect PERSON
# Access GPE
# RegEx PERSON
# Succeed PERSON
# Instructor PERSON
# Kevin Trainor PERSON
# Roger Ho PERSON
# Roger PERSON
# the Request Center ORG
# The Request Center ORG
# JIRA Service Desk PERSON
# 847-650-9706 CARDINAL
# Online Lab Sessions PERSON
# Tuesday DATE
# 6:30 PM to 7:30 PM TIME
# Online Lab PERSON
# the Blackboard Collaborate Ultra ORG
# Framework Evaluation Paper ORG
# Final Project ORG
# Lab Sessions PERSON
# Blackboard PERSON
# Ultra NORP
# Today DATE
# Model-View-Controller ORG
# MVC ORG
# Django ORG
# Python ORG
# Django GPE
# Django Web PRODUCT
# Prerequisites ORG
# HTML ORG
# CSS ORG
# PHP ORG
# 1 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# Django ORG
# 4 CARDINAL
# Django PERSON
# Models ORG
# User PERSON
# Session PERSON
# 5 CARDINAL
# Django NORP
# ...

# %% [markdown]
# #Not too successful!
